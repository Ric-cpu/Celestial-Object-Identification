# %%
import sys
import platform
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

print("Python:", sys.version.split()[0])
print("OS:", platform.platform())
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("scikit-learn:", sklearn.__version__)
print("matplotlib:", matplotlib.__version__)
print("seaborn:", sns.__version__)

try:
    import jupyter
    print("jupyter:", jupyter.__version__)
except Exception:
    print("jupyter: not available as import")

try:
    import astroquery
    print("astroquery:", astroquery.__version__)
except Exception:
    print("astroquery: not installed / not available")
# Out:
# Python: 3.13.0
# OS: Windows-11-10.0.26200-SP0
# pandas: 2.3.3
# numpy: 2.3.5
# scikit-learn: 1.7.2
# matplotlib: 3.10.7
# seaborn: 0.13.2
# jupyter: not available as import
# astroquery: 0.4.11
